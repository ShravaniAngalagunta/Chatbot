# %%
import os
from groq import Groq

# Initialize the Groq client. 
# It automatically picks up the key if you set the 'GROQ_API_KEY' environment variable.
# Otherwise, paste your string key directly into the argument below.
client = Groq(api_key=os.environ.get("GROQ_API_KEY", "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"))

def chat_with_groq(prompt):
    # Uses the modern client-driven chat completion format
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role": "user", "content": prompt}]
    )

    # Retrieves the cleaned response text payload
    return response.choices[0].message.content.strip()

if __name__ == "__main__":
    while True:
        user_input = input("You: ")
        if user_input.lower() in ["quit", "exit", "bye"]:
            break

        response = chat_with_groq(user_input)
        print("Chatbot: ", response)
# Out:
# You:  Hi
# Chatbot:  How can I help you today?
# You:  It's so hot today and I am feeling dizzy what to do?
# Chatbot:  I'm glad you reached out for help. Feeling dizzy and hot can be a combination of uncomfortable symptoms. Here are some steps you can take to help alleviate your condition:
#
# 1. **Hydrate, hydrate, hydrate**: Drink plenty of water or electrolyte-rich fluids like coconut water or sports drinks to replace lost fluids and electrolytes.
# 2. **Take a cool break**: Move to a cooler place or take a break in a shaded area to get some relief from the heat.
# 3. **Rest and recover**: Sit or lie down in a quiet space and rest for a while. This can help your body conserve energy and recover from heat stress.
# 4. **Remove excess clothing**: Wear lightweight, loose-fitting clothes to allow for good airflow and heat dissipation.
# 5. **Avoid strenuous activities**: Try to avoid any physical exertion that can exacerbate your symptoms.
# ...
